# %%
import pandas as pd

# %%
drg_cert_2024_path = "data/drg-cert-2024-fixed.csv"
drg_cert_2024_output_path = "data/drg-cert-2024-fixed_expected_output.csv"

input = pd.read_csv(drg_cert_2024_path, sep=";", header=None)
output = pd.read_csv(drg_cert_2024_output_path, sep=";")
output
# Out:
#                   id  vek  hmotnost  umela_plucna_ventilacia  \
# 0      P019/HP663449   80       NaN                        0
# 1      P063/HP678806   63       NaN                        0
# 2      P017/HP223780   75       NaN                        0
# 3      P067/HP354818   50       NaN                        0
# 4      P027/HP613843    0    2520.0                        0
# ...              ...  ...       ...                      ...
# 49995  P019/HP471377   63       NaN                        0
# 49996  P054/HP551312   62       NaN                        0
# 49997  P031/HP332311   71       NaN                        0
# 49998  P072/HP567440   28       NaN                        0
# 49999  P035/HP540673   52       NaN                        0
#
#                                                 diagnozy  \
# 0                        N178~D508~E1160~I1000~I480~N183
# 1                                            M8008~M4856
# 2      H058~E782~E790~H162~H405~H532~K219~M5496~N119~...
# ...

# %%
output
